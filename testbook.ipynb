# %% [markdown]
# # Testbook!
#
# A bunch of cells running different diagnostics.

# %% [markdown]
# ## Current conda environment

# %%
# !echo $CONDA_PREFIX
# Out:
# /home/yjunteng/anaconda3/envs/py310

# %% [markdown]
# ## Testing CUDA availability
#
# From [HF Hub](https://huggingface.co/docs/hub/spaces-gpus), you will need to use torch to do this.

# %%
import torch
cuda_avail = torch.cuda.is_available()
print(f"Is CUDA available: {cuda_avail}")
if cuda_avail:
    print(f"CUDA device: {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("No CUDA devices found")
# Out:
# Is CUDA available: True
# CUDA device: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ### Testing CUDA Multiple Devices
#
# Shin Youn set some environment variables, that Alicia also used. Try this:

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" # To order device based on pci bus id
os.environ["CUDA_VISIBLE_DEVICES"] = "2,3" # To use GPU 2 and 3

torch.cuda.current_device()
# Out:
# 0

# %% [markdown]
# ### Testing HuggingFace
#
# The code below should run quickly IF the datasets are already available.
#
# TODO: make this a check that does not load model into ram.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("tscholak/cxmefzzi")
model = AutoModelForSeq2SeqLM.from_pretrained("tscholak/cxmefzzi")

# %% [markdown]
# ### Cached Spider Dataset

# %%
from datasets import load_dataset
dataset = load_dataset("spider")
# Out:
# Downloading builder script: 100%|██████████| 3.94k/3.94k [00:00<00:00, 3.40MB/s]
# Downloading metadata: 100%|██████████| 1.97k/1.97k [00:00<00:00, 1.59MB/s]
# Downloading readme: 100%|██████████| 4.69k/4.69k [00:00<00:00, 3.81MB/s]
# Downloading and preparing dataset spider/spider to /home/yjunteng/.cache/huggingface/datasets/spider/spider/1.0.0/4e5143d825a3895451569c8b9b55432b91a4bc2d04d390376c950837f4680daa...
# Downloading data: 100%|██████████| 99.7M/99.7M [00:05<00:00, 19.9MB/s]
# Dataset spider downloaded and prepared to /home/yjunteng/.cache/huggingface/datasets/spider/spider/1.0.0/4e5143d825a3895451569c8b9b55432b91a4bc2d04d390376c950837f4680daa. Subsequent calls will reuse this data.
# 100%|██████████| 2/2 [00:00<00:00, 556.61it/s]

# %% [markdown]
# # Running Model
# We now have the model loaded from the pretrained version.
