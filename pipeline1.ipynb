# %% [markdown]
# # Pipeline 1

# %%
from pipeline import Falcon2Linker, SerialAnnotator, T5Converter
from pprint import pprint

# %%
linker = Falcon2Linker()
annotator = SerialAnnotator()
converter = T5Converter()

# %%
utterance = "Who is the wife of Barack Obama"

# %%
linked = linker.link(utterance)
pprint("Linked")
pprint(linked)

pprint("Annotated")
annotated = annotator.annotate(**linked)
pprint(annotated)

pprint("Converted")
converted = converter.preprocess_inputs(**annotated)
pprint(converted)
# Out:
# 'Linked'
# {'ents': [{'id': 'Q76',
#            'prefix': 'wd:',
#            'uri': 'http://www.wikidata.org/entity/Q76'},
#           {'id': 'Q649593',
#            'prefix': 'wd:',
#            'uri': 'http://www.wikidata.org/entity/Q649593'},
#           {'id': 'Q4808526',
#            'prefix': 'wd:',
#            'uri': 'http://www.wikidata.org/entity/Q4808526'},
#           {'id': 'Q4858106',
#            'prefix': 'wd:',
#            'uri': 'http://www.wikidata.org/entity/Q4858106'},
#           {'id': 'Q643049',
#            'prefix': 'wd:',
#            'uri': 'http://www.wikidata.org/entity/Q643049'}],
#  'rels': [{'id': 'P26',
#            'prefix': 'wdt:',
#            'uri': 'http://www.wikidata.org/prop/direct/P26'},
#           {'id': 'P2848',
#            'prefix': 'wdt:',
#            'uri': 'http://www.wikidata.org/prop/direct/P2848'},
#           {'id': 'P140',
#            'prefix': 'wdt:',
#            'uri': 'http://www.wikidata.org/prop/direct/P140'},
#           {'id': 'P451',
#            'prefix': 'wdt:',
#            'uri': 'http://www.wikidata.org/prop/direct/P451'},
#           {'id': 'P600',
#            'prefix': 'wdt:',
#            'uri': 'http://www.wikidata.org/prop/direct/P600'}],
#  'utterance': 'Who is the wife of Barack Obama'}
# 'Annotated'
# {'fragments': ['[DEF]',
#                'wd:',
#                'Q76 Barack Obama',
#                '[DEF]',
#                'wd:',
#                'Q649593 Barack Obama Sr.',
#                '[DEF]',
#                'wd:',
#                'Q4808526 assassination threats against Barack Obama',
#                '[DEF]',
#                'wd:',
#                'Q4858106 Barack Obama Academy',
#                '[DEF]',
#                'wd:',
#                'Q643049 family of Barack Obama',
#                '[DEF]',
#                'wdt:',
#                'P26 spouse',
#                '[DEF]',
#                'wdt:',
#                'P2848 Wi-Fi access',
#                '[DEF]',
#                'wdt:',
#                'P140 religion or worldview',
#                '[DEF]',
#                'wdt:',
#                'P451 unmarried partner',
#                '[DEF]',
#                'wdt:',
#                'P600 Wine AppDB ID'],
#  'utterance': 'Who is the wife of Barack Obama'}
# 'Converted'
# ('Who is the wife of Barack Obama <extra_id_59> <extra_id_53> Q76 Barack Obama '
#  '<extra_id_59> <extra_id_53> Q649593 Barack Obama Sr. <extra_id_59> '
#  '<extra_id_53> Q4808526 assassination threats against Barack Obama '
#  '<extra_id_59> <extra_id_53> Q4858106 Barack Obama Academy <extra_id_59> '
#  '<extra_id_53> Q643049 family of Barack Obama <extra_id_59> <extra_id_54> P26 '
#  'spouse <extra_id_59> <extra_id_54> P2848 Wi-Fi access <extra_id_59> '
#  '<extra_id_54> P140 religion or worldview <extra_id_59> <extra_id_54> P451 '
#  'unmarried partner <extra_id_59> <extra_id_54> P600 Wine AppDB ID')

# %%
def pipe(utterance, wikisparql):
    linked = linker.link(utterance)
    annotated = annotator.annotate(**linked)
    converted = converter.preprocess(**annotated, wikisparql=wikisparql)
    return linked, annotated, converted

# %% [markdown]
# ## Data

# %%
from pathlib import Path
import pandas as pd
import json

data_path = Path("data") / "lcquad2" / "train.json"

# %%
with open(data_path) as f:
  data_dict = json.load(f)
df = pd.DataFrame.from_dict(data_dict)
df.head()
# Out:
#                                        NNQT_question    uid  \
# 0  What is the {periodical literature} for {mouth...  19719
# 1  What is {child of} of {husband} of {Ranavalona...  15554
# 2  Did {Jeff_Bridges} {occupation} {Lane Chandler...    974
# 3  What is {prequel of} of {phase of matter} of {...  15803
# 4           What is <operating income> of <Qantas> ?  27610
#
#                                 subgraph  template_index  \
# 0                  simple question right              65
# 1                          left-subgraph               8
# 2  boolean double one_hop right subgraph             474
# 3                         right-subgraph              33
# 4                                 center            1907
#
#                                             question  \
# 0  What periodical literature does Delta Air Line...
# 1        Who is the child of Ranavalona I's husband?
# 2  Is it true Jeff_Bridges occupation Lane Chandl...
# 3  What is the pre-requisite of phase matter of G...
# 4          Which is the operating income for Qantas?
#
#                                      sparql_wikidata  \
# 0   select distinct ?obj where { wd:Q188920 wdt:P...
# 1  SELECT ?answer WHERE { wd:Q169794 wdt:P26 ?X ....
# 2  ASK WHERE { wd:Q174843 wdt:P106 wd:Q1804811 . ...
# 3  SELECT ?answer WHERE { wd:Q675176 wdt:P515 ?X ...
# 4  select distinct ?answer where { wd:Q32491 wdt:...
#
#                                     sparql_dbpedia18  \
# 0  select distinct ?obj where { ?statement <http:...
# 1  SELECT ?answer WHERE { ?statement1 <http://www...
# 2   ASK { ?statement1 <http://www.w3.org/1999/02/...
# 3  SELECT ?answer WHERE { ?statement1 <http://www...
# 4  select distinct ?answer where { ?statement <ht...
#
#                                template answer template_id  \
# 0         <S P ?O ; ?O instanceOf Type>     []           1
# 1                  C RCD xD . xD RDE ?E     []           5
# 2  Ask (ent-pred-obj1` . ent-pred-obj2)     []           2
# 3                  E REF xF . xF RFG ?G     []           2
# 4                              E REF ?F     []         1.1
#
#                                 paraphrased_question
# 0  What is Delta Air Line's periodical literature...
# 1  What is the name of Ranavalona I's husband's c...
# 2  Are Jeff Bridges and Lane Chandler both photog...
# 3  What range are the papers at the Monique Genon...
# 4                                                 []

# %%
responses = []
for i, data in enumerate(data_dict):
    print("Pipeline iter", i)
    question = data["question"]
    answer = data["sparql_wikidata"]
    try:
        linked, annotated, converted = pipe(question, answer)
    except Exception as e:
        print(e)
        continue
    responses.append([linked, annotated, converted])
    if (i % 10) == 0:
        with open(f"falcon_links/0/link_{i}.json", "w") as f:
            json.dump(responses, f, indent=2, separators=(',',':'))
# Out:
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8efb0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8ee30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a980>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032c80>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b494cead0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bbe0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19111ff0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bc10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbc10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032a40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48fb3fd0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f3d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b191122c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112410>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8fbe0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a7d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b490323b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccb9a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bb50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112830>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bbe0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b494ce290>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032c80>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4945f9d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f5e0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b191121d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112470>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f2b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a590>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032e90>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbca0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bd00>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112a10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bca0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b494cee60>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032d10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4945f340>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8ed40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112c80>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19111c60>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f160>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a3e0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032c50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccb9a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bcd0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112530>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bd00>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbee0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b490323e0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4945f340>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8fb50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112320>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112f20>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8feb0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a380>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032aa0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbd90>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bb50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112c50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b5b47ece0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b494ccb80>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032440>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f280>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8fb50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b191130d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19112b00>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f910>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a890>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032aa0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbfa0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3beb0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19113100>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bf70>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbfa0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b490323b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4945f340>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8ed10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b191125c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19111c30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48d8f130>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4906a350>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49032e90>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbca0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b48c3bbb0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b19111b10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b5b47ece0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b49ccbc10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b490327a0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# HTTPConnectionPool(host='localhost', port=6000): Max retries exceeded with url: /linker (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4b4945cc40>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
with open("weekend.json", "w") as f:
  json.dump(responses, f, separators=(',', ': '))
